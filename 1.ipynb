# %%
# pip install camelot-py[cv] # do incase camelot is not installed in your conda.

# %%
import camelot
tables = camelot.read_pdf(filepath='al.pdf',flavor='stream',edge_tol=1500)

# %%
temp_df = tables[1].df
temp_df = temp_df[2:52]

# %%
temp_df
# Out:
#                                                     0 1        2        3  \
# 2   Employment Growth Rates (% change from year ag...      Q2-21    Q1-21
# 3   Total Nonfarm (share of trailing four quarter ...       6.7%    -2.9%
# 4                                 Manufacturing (13%)       9.8%    -1.5%
# 5      Other (non-manufacturing) Goods-Producing (5%)      -1.6%    -1.6%
# 6                     Private Service-Providing (63%)       8.3%    -3.5%
# 7                                    Government (19%)       2.0%    -2.2%
# 8   Unemployment Rate (% of labor force, seasonall...       3.4%     4.0%
# 9   Other Indicators (% change of 4-qtr moving tot...      Q2-21    Q1-21
# 10                         Single-Family Home Permits      23.7%    16.9%
# 11                       Multifamily Building Permits      -4.1%    42.1%
# 12            Home Price Index (change from year ago)      10.6%     7.3%
# 13  Nonbusiness Bankruptcy Filings per 1000 people...       2.89     3.15
# ...

# %%
stripped = text.split(sep, 1)[0]

# %%
(temp_df[temp_df[0] == 'Home Price Index (change from year ago)'][0]).split('(', 1)[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7150/838254021.py in <module>
# ----> 1 (temp_df[temp_df[0] == 'Home Price Index (change from year ago)'][0]).split('(', 1)[0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
string = 'Home Price Index (change from year ago) 	'

# %%
string.split('(', 1)[0]
# Out:
# 'Home Price Index '

# %%
remove_from_bracket = lambda text : text.split('(', 1)[0]
remove_spaces = lambda text : text.strip()

# %%
temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)
# Out:
# /tmp/ipykernel_7150/45471323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)

# %%
temp_df
# Out:
#                                                  0 1        2        3  \
# 2                          Employment Growth Rates      Q2-21    Q1-21
# 3                                    Total Nonfarm       6.7%    -2.9%
# 4                                    Manufacturing       9.8%    -1.5%
# 5                                            Other      -1.6%    -1.6%
# 6                        Private Service-Providing       8.3%    -3.5%
# 7                                       Government       2.0%    -2.2%
# 8                                Unemployment Rate       3.4%     4.0%
# 9                                 Other Indicators      Q2-21    Q1-21
# 10                      Single-Family Home Permits      23.7%    16.9%
# 11                    Multifamily Building Permits      -4.1%    42.1%
# 12                                Home Price Index      10.6%     7.3%
# 13  Nonbusiness Bankruptcy Filings per 1000 people       2.89     3.15
# ...

# %%
temp_df['Oil (m³)'] = temp_df['Oil (m³)'].map(remove_space)

# %%
temp_df.to_csv("test.csv")

# %%
# pd.set_option('display.width', 1000)

# %%
# pd.set_option('display.expand_frame_repr', False)

# %%
df = temp_df[temp_df[0] == 'Construction & Development']

# %%
df = temp_df[temp_df[0] == 'Agriculture']

# %%
df[]
# Out:
#               0 1   2   3   4   5   6
# 51  Agriculture    13  14  16  15  17

# %%
import pandas as pd

# %%
temp_df = pd.DataFrame()

# %%
temp_df = tables[0].df

# %%
import re

txt = "The rain in Spain"
if 'ai' in txt:
    print("All")
# Out:
# All

# %% [markdown]
# ```
# Requirements :
#
# Past-Due and Nonaccrual Loans / Total Loans - Asset Quality
# Noncurrent Loans / Total Loans 	- Asset Quality
#
#
# ```

# %%
dict_fetch = {'hebron': ['heb_oil_', 2017, 'hebstats', 'hepro'],
                  'hibernia': ['hib_oil_', 1997, 'hibstats', 'hpro'],
                  'north_amethyst': ['na_oil_', 2010, 'nastats', 'npro'],
                  'terra_nova': ['tn_oil_', 2002, 'tnstats', 'tpro'],
                  'white_rose': ['wr_oil_', 2005, 'wrstats', 'wpro']}

# %%
dict_fetch.keys()
# Out:
# dict_keys(['hebron', 'hibernia', 'north_amethyst', 'terra_nova', 'white_rose'])

# %%
for key in dict_fetch.keys():
    print(key)
    
    print(dict_fetch[key])
# Out:
# hebron
# ['heb_oil_', 2017, 'hebstats', 'hepro']
# hibernia
# ['hib_oil_', 1997, 'hibstats', 'hpro']
# north_amethyst
# ['na_oil_', 2010, 'nastats', 'npro']
# terra_nova
# ['tn_oil_', 2002, 'tnstats', 'tpro']
# white_rose
# ['wr_oil_', 2005, 'wrstats', 'wpro']

# %%
dict_fetch['hebron']
# Out:
# ['heb_oil_', 2017, 'hebstats', 'hepro']
