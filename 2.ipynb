# %%
import numpy as np
import camelot
import pandas as pd

# %%
tables = camelot.read_pdf(filepath='al.pdf',flavor='stream',edge_tol=1500)
temp_df = tables[1].df
remove_from_bracket = lambda text : text.split('(', 1)[0]
remove_spaces = lambda text : text.strip()
temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)
temp_df = temp_df[0:52]
temp_df = temp_df.drop([1], axis=1)
column_name_1 = temp_df[0][1]
temp_df = temp_df.replace(r'^\s*$', np.nan, regex=True)
temp_df = temp_df.dropna()
temp_df = temp_df.reset_index(drop = True)
temp_df.columns = temp_df.iloc[0]
temp_df = temp_df.drop(temp_df.index[0])
temp_df.rename(columns={'Employment Growth Rates': column_name_1}, inplace=True)
temp_df = temp_df.reset_index(drop = True)

# %%
temp_df
# Out:
# 0                              ECONOMIC INDICATORS    Q2-21    Q1-21    Q2-20  \
# 0                                    Total Nonfarm     6.7%    -2.9%    -9.0%
# 1                                    Manufacturing     9.8%    -1.5%    -9.5%
# 2                                            Other    -1.6%    -1.6%    -2.9%
# 3                        Private Service-Providing     8.3%    -3.5%   -10.9%
# 4                                       Government     2.0%    -2.2%    -4.0%
# 5                                Unemployment Rate     3.4%     4.0%     9.6%
# 6                                 Other Indicators    Q2-21    Q1-21    Q2-20
# 7                       Single-Family Home Permits    23.7%    16.9%    12.7%
# 8                     Multifamily Building Permits    -4.1%    42.1%   101.4%
# 9                                 Home Price Index    10.6%     7.3%     5.3%
# 10  Nonbusiness Bankruptcy Filings per 1000 people     2.89     3.15     3.30
# 11                             General Information    Q2-21    Q1-21    Q2-20
# 12                                    Institutions      103      107      110
# 13                                    Total Assets  305,863  309,320  293,782
# 14                                New Institutions        0        1        1
# 15                       Subchapter S Institutions       35       35       36
# 16                                   Asset Quality    Q2-21    Q1-21    Q2-20
# 17     Past-Due and Nonaccrual Loans / Total Loans     0.80     1.00     1.00
# 18                  Noncurrent Loans / Total Loans     0.43     0.44     0.49
# 19          Loan and Lease Allowance / Total Loans     1.33     1.34     1.23
# 20     Loan and Lease Allowance / Noncurrent Loans     2.94     2.92     2.17
# 21                   Net Loan Losses / Total Loans     0.02     0.00     0.04
# 22                              Capital / Earnings    Q2-21    Q1-21    Q2-20
# 23                                 Tier 1 Leverage    10.08    10.23    10.61
# 24                                Return on Assets     1.03     0.97     0.98
# 25                         Pretax Return on Assets     1.24     1.16     1.14
# 26                             Net Interest Margin     3.28     3.21     3.70
# 27                         Yield on Earning Assets     3.69     3.65     4.37
# 28                  Cost of Funding Earning Assets     0.34     0.37     0.68
# 29                       Provisions to Avg. Assets     0.03     0.00     0.13
# 30               Noninterest Income to Avg. Assets     0.59     0.58     0.58
# 31                         Overhead to Avg. Assets     2.45     2.47     2.76
# 32                           Liquidity/Sensitivity    Q2-21    Q1-21    Q2-20
# 33                             Net Loans to Assets    50.27    50.60    57.94
# 34                       Noncore Funding to Assets     7.45     7.78     8.77
# 35                      Long-term Assets to Assets    34.00    32.95    28.57
# 36                               Brokered Deposits       29       31       32
# 37                     Brokered Deposits to Assets     2.74     2.60     3.00
# 38                       Commercial and Industrial       80       84      101
# 39                          Commercial Real Estate      187      177      176
# 40                      Construction & Development       40       38       34
# 41             Multifamily Residential Real Estate        8        8        8
# 42                      Nonresidential Real Estate      119      113      115
# 43                         Residential Real Estate      121      123      127
# 44                                        Consumer       18       19       20
# 45                                     Agriculture       13       14       16
#
# 0      2020     2019
# 0     -4.3%     1.5%
# 1     -4.1%     0.7%
# 2     -1.1%     4.7%
# 3     -5.3%     1.4%
# 4     -1.9%     1.3%
# 5      6.0%     3.0%
# 6      2020     2019
# 7     18.8%     7.9%
# 8     21.7%    41.0%
# 9      5.9%     5.0%
# 10     3.69     5.41
# 11     2020     2019
# 12      107      110
# 13  300,540  260,987
# 14        1        1
# 15       35       35
# 16     2020     2019
# 17     1.11     1.63
# 18     0.48     0.66
# 19     1.31     1.23
# 20     2.27     1.80
# 21     0.07     0.12
# 22     2020     2019
# 23    10.33    11.38
# 24     0.93     1.07
# 25     1.15     1.27
# 26     3.56     3.86
# 27     4.18     4.71
# 28     0.58     0.77
# 29     0.13     0.11
# 30     0.57     0.65
# 31     2.69     2.92
# 32     2020     2019
# 33    53.96    60.67
# 34     8.01     8.85
# 35    30.72    28.99
# 36       31       31
# 37     2.68     2.51
# 38       81       65
# 39      184      172
# 40       34       33
# 41        7        7
# 42      122      109
# 43      130      132
# 44       19       22
# 45       15       17

# %%
dict_fetch = {"Past-Due and Nonaccrual Loans / Total Loans" : "Asset Quality",
              "Noncurrent Loans / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Noncurrent Loans" : "Asset Quality",
              "Net Loan Losses / Total Loans" : "Asset Quality",
              "Return on Assets" : "Earnings",
              "Net Interest Margin" : "Earnings",
              "Yield on Earning Assets" : "Earnings",
              "Cost of Funding Earning Assets" : "Earnings",
              "Provisions to Avg. Assets" : "Earnings",
              "Overhead to Avg. Assets" : "Earnings",
              "Net Loans to Assets" : "Liquidity",
              "Long-term Assets to Assets" : "Liquidity"
            }

# %%
filter_df = pd.DataFrame()
filter_df['Category'] = ""

# %%
for i in range(len(temp_df)):
#     print(temp_df['ECONOMIC INDICATORS'][i])
    eco_indi = temp_df['ECONOMIC INDICATORS'][i]
    for key,value in dict_fetch.items():
        if key == eco_indi:
#             print(eco_indi)
#             print(temp_df[temp_df['ECONOMIC INDICATORS'] == temp_df['ECONOMIC INDICATORS'][i]])
#             print(temp_df[temp_df['ECONOMIC INDICATORS'] == eco_indi])
            filter_df = filter_df.append(temp_df[temp_df['ECONOMIC INDICATORS'] == eco_indi])
            filter_df['Category'][i] = value

# %%
filter_df
# Out:
#          Category                          ECONOMIC INDICATORS  Q2-21  Q1-21  \
# 17  Asset Quality  Past-Due and Nonaccrual Loans / Total Loans   0.80   1.00
# 18  Asset Quality               Noncurrent Loans / Total Loans   0.43   0.44
# 19  Asset Quality       Loan and Lease Allowance / Total Loans   1.33   1.34
# 20  Asset Quality  Loan and Lease Allowance / Noncurrent Loans   2.94   2.92
# 21  Asset Quality                Net Loan Losses / Total Loans   0.02   0.00
# 24       Earnings                             Return on Assets   1.03   0.97
# 26       Earnings                          Net Interest Margin   3.28   3.21
# 27       Earnings                      Yield on Earning Assets   3.69   3.65
# 28       Earnings               Cost of Funding Earning Assets   0.34   0.37
# 29       Earnings                    Provisions to Avg. Assets   0.03   0.00
# 31       Earnings                      Overhead to Avg. Assets   2.45   2.47
# 33      Liquidity                          Net Loans to Assets  50.27  50.60
# 35      Liquidity                   Long-term Assets to Assets  34.00  32.95
#
#     Q2-20   2020   2019
# 17   1.00   1.11   1.63
# 18   0.49   0.48   0.66
# 19   1.23   1.31   1.23
# 20   2.17   2.27   1.80
# 21   0.04   0.07   0.12
# 24   0.98   0.93   1.07
# 26   3.70   3.56   3.86
# 27   4.37   4.18   4.71
# 28   0.68   0.58   0.77
# 29   0.13   0.13   0.11
# 31   2.76   2.69   2.92
# 33  57.94  53.96  60.67
# 35  28.57  30.72  28.99

# %%
filter_df = filter_df[['ECONOMIC INDICATORS', 'Q2-21', 'Q1-21', 'Q2-20', '2020', '2019', 'Category']]

# %%
filter_df
# Out:
#                             ECONOMIC INDICATORS  Q2-21  Q1-21  Q2-20   2020  \
# 17  Past-Due and Nonaccrual Loans / Total Loans   0.80   1.00   1.00   1.11
# 18               Noncurrent Loans / Total Loans   0.43   0.44   0.49   0.48
# 19       Loan and Lease Allowance / Total Loans   1.33   1.34   1.23   1.31
# 20  Loan and Lease Allowance / Noncurrent Loans   2.94   2.92   2.17   2.27
# 21                Net Loan Losses / Total Loans   0.02   0.00   0.04   0.07
# 24                             Return on Assets   1.03   0.97   0.98   0.93
# 26                          Net Interest Margin   3.28   3.21   3.70   3.56
# 27                      Yield on Earning Assets   3.69   3.65   4.37   4.18
# 28               Cost of Funding Earning Assets   0.34   0.37   0.68   0.58
# 29                    Provisions to Avg. Assets   0.03   0.00   0.13   0.13
# 31                      Overhead to Avg. Assets   2.45   2.47   2.76   2.69
# 33                          Net Loans to Assets  50.27  50.60  57.94  53.96
# 35                   Long-term Assets to Assets  34.00  32.95  28.57  30.72
#
#      2019       Category
# 17   1.63  Asset Quality
# 18   0.66  Asset Quality
# 19   1.23  Asset Quality
# 20   1.80  Asset Quality
# 21   0.12  Asset Quality
# 24   1.07       Earnings
# 26   3.86       Earnings
# 27   4.71       Earnings
# 28   0.77       Earnings
# 29   0.11       Earnings
# 31   2.92       Earnings
# 33  60.67      Liquidity
# 35  28.99      Liquidity

# %%
filter_df = filter_df.reset_index(drop = True)

# %%
filter_df
# Out:
#                             ECONOMIC INDICATORS  Q2-21  Q1-21  Q2-20   2020  \
# 0   Past-Due and Nonaccrual Loans / Total Loans   0.80   1.00   1.00   1.11
# 1                Noncurrent Loans / Total Loans   0.43   0.44   0.49   0.48
# 2        Loan and Lease Allowance / Total Loans   1.33   1.34   1.23   1.31
# 3   Loan and Lease Allowance / Noncurrent Loans   2.94   2.92   2.17   2.27
# 4                 Net Loan Losses / Total Loans   0.02   0.00   0.04   0.07
# 5                              Return on Assets   1.03   0.97   0.98   0.93
# 6                           Net Interest Margin   3.28   3.21   3.70   3.56
# 7                       Yield on Earning Assets   3.69   3.65   4.37   4.18
# 8                Cost of Funding Earning Assets   0.34   0.37   0.68   0.58
# 9                     Provisions to Avg. Assets   0.03   0.00   0.13   0.13
# 10                      Overhead to Avg. Assets   2.45   2.47   2.76   2.69
# 11                          Net Loans to Assets  50.27  50.60  57.94  53.96
# 12                   Long-term Assets to Assets  34.00  32.95  28.57  30.72
#
#      2019       Category
# 0    1.63  Asset Quality
# 1    0.66  Asset Quality
# 2    1.23  Asset Quality
# 3    1.80  Asset Quality
# 4    0.12  Asset Quality
# 5    1.07       Earnings
# 6    3.86       Earnings
# 7    4.71       Earnings
# 8    0.77       Earnings
# 9    0.11       Earnings
# 10   2.92       Earnings
# 11  60.67      Liquidity
# 12  28.99      Liquidity

# %%
download_link = 'https://www.fdic.gov//analysis/state-profiles/atlanta/al.pdf'

# %%
filter_df['state_alias'] = (download_link.split('/')[-1]).split('.')[0]

# %%
filter_df
# Out:
#                             ECONOMIC INDICATORS  Q2-21  Q1-21  Q2-20   2020  \
# 0   Past-Due and Nonaccrual Loans / Total Loans   0.80   1.00   1.00   1.11
# 1                Noncurrent Loans / Total Loans   0.43   0.44   0.49   0.48
# 2        Loan and Lease Allowance / Total Loans   1.33   1.34   1.23   1.31
# 3   Loan and Lease Allowance / Noncurrent Loans   2.94   2.92   2.17   2.27
# 4                 Net Loan Losses / Total Loans   0.02   0.00   0.04   0.07
# 5                              Return on Assets   1.03   0.97   0.98   0.93
# 6                           Net Interest Margin   3.28   3.21   3.70   3.56
# 7                       Yield on Earning Assets   3.69   3.65   4.37   4.18
# 8                Cost of Funding Earning Assets   0.34   0.37   0.68   0.58
# 9                     Provisions to Avg. Assets   0.03   0.00   0.13   0.13
# 10                      Overhead to Avg. Assets   2.45   2.47   2.76   2.69
# 11                          Net Loans to Assets  50.27  50.60  57.94  53.96
# 12                   Long-term Assets to Assets  34.00  32.95  28.57  30.72
#
#      2019       Category state_alias
# 0    1.63  Asset Quality          al
# 1    0.66  Asset Quality          al
# 2    1.23  Asset Quality          al
# 3    1.80  Asset Quality          al
# 4    0.12  Asset Quality          al
# 5    1.07       Earnings          al
# 6    3.86       Earnings          al
# 7    4.71       Earnings          al
# 8    0.77       Earnings          al
# 9    0.11       Earnings          al
# 10   2.92       Earnings          al
# 11  60.67      Liquidity          al
# 12  28.99      Liquidity          al
