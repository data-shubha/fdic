# %%
import os
import camelot
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
dict_fetch = {"Past-Due and Nonaccrual Loans / Total Loans" : "Asset Quality",
              "Noncurrent Loans / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Noncurrent Loans" : "Asset Quality",
              "Net Loan Losses / Total Loans" : "Asset Quality",
              "Return on Assets" : "Earnings",
              "Net Interest Margin" : "Earnings",
              "Yield on Earning Assets" : "Earnings",
              "Cost of Funding Earning Assets" : "Earnings",
              "Provisions to Avg. Assets" : "Earnings",
              "Overhead to Avg. Assets" : "Earnings",
              "Net Loans to Assets" : "Liquidity",
              "Long-term Assets to Assets" : "Liquidity"
            }

# %%
files_path = '/home/shubha/work/byteiq_tasks/fdic/download/'

# %%
download_list = os.listdir(files_path)
download_list.sort()

# %%
for file in download_list:
    file_path = files_path + file
#     print(file_path)

# %%
file_path = '/home/shubha/work/byteiq_tasks/fdic/download/ak.pdf'

# %%
tables = camelot.read_pdf(filepath=file_path,flavor='stream',edge_tol=1500)

# %%
tables[0]
# Out:
# <Table shape=(62, 7)>

# %%
temp_df = tables[0].df

# %%
remove_from_bracket = lambda text : text.split('(', 1)[0]
remove_spaces = lambda text : text.strip()
temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)

# %%
temp_df = temp_df.drop([1], axis=1)

# %%
temp_df
# Out:
#                                                  0            2       3  \
# 0
# 1
# 2
# 3                              ECONOMIC INDICATORS
# 4                          Employment Growth Rates        Q2-21   Q1-21
# 5                                    Total Nonfarm         6.9%   -7.2%
# 6                                    Manufacturing         9.2%   -3.6%
# 7                                            Other         3.2%  -10.6%
# 8                        Private Service-Providing         8.7%   -8.7%
# 9                                       Government         3.5%   -2.8%
# 10                               Unemployment Rate         6.6%    6.6%
# 11                                Other Indicators        Q2-21   Q1-21
# 12                      Single-Family Home Permits        25.0%   10.6%
# 13                    Multifamily Building Permits       -29.0%  -40.8%
# 14                                Home Price Index         6.8%    4.1%
# 15  Nonbusiness Bankruptcy Filings per 1000 people         0.32    0.32
# 16                                  BANKING TRENDS
# 17                             General Information        Q2-21   Q1-21
# 18                                    Institutions            5       5
# 19                                    Total Assets        9,599   8,955
# 20                                New Institutions            0       0
# 21                       Subchapter S Institutions            1       1
# 22                                   Asset Quality        Q2-21   Q1-21
# 23     Past-Due and Nonaccrual Loans / Total Loans         0.84    0.92
# 24                  Noncurrent Loans / Total Loans         0.62    0.76
# 25          Loan and Lease Allowance / Total Loans         1.69    1.59
# 26     Loan and Lease Allowance / Noncurrent Loans         2.39    1.70
# 27                   Net Loan Losses / Total Loans         0.00   -0.01
# 28                              Capital / Earnings        Q2-21   Q1-21
# 29                                 Tier 1 Leverage         9.82   10.44
# 30                                Return on Assets         1.30    1.41
# 31                         Pretax Return on Assets         1.48    1.55
# 32                             Net Interest Margin         2.96    3.13
# 33                         Yield on Earning Assets         3.12    3.16
# 34                  Cost of Funding Earning Assets         0.16    0.17
# 35                       Provisions to Avg. Assets         0.08    0.14
# 36               Noninterest Income to Avg. Assets         0.99    1.01
# 37                         Overhead to Avg. Assets         2.90    2.93
# 38                           Liquidity/Sensitivity        Q2-21   Q1-21
# 39                             Net Loans to Assets        42.26   45.98
# 40                       Noncore Funding to Assets         3.70    3.98
# 41                      Long-term Assets to Assets        37.94   38.67
# 42                               Brokered Deposits            0       0
# 43                     Brokered Deposits to Assets         0.00    0.00
# 44                             Loan Concentrations
# 45                                                        Q2-21   Q1-21
# 46                       Commercial and Industrial          109     118
# 47                          Commercial Real Estate          183     190
# 48                      Construction & Development           39      38
# 49             Multifamily Residential Real Estate           13      13
# 50                      Nonresidential Real Estate          152     155
# 51                         Residential Real Estate           50      63
# 52                                        Consumer            3       3
# 53                                     Agriculture            7       7
# 54                                 BANKING PROFILE
# 55                                                  Deposits ($
# 56                         Largest Deposit Markets    millions)
# 57                                   Anchorage, AK        9,374
# 58                                   Fairbanks, AK        1,947
# 59
# 60
# 61
#
#                                4              5             6
# 0
# 1                                                      Alaska
# 2
# 3
# 4                          Q2-20           2020          2019
# 5                         -13.7%          -8.7%          0.7%
# 6                          -8.7%         -11.3%          3.6%
# 7                         -12.1%          -7.8%          4.5%
# 8                         -16.5%         -10.5%          0.5%
# 9                          -8.0%          -3.8%         -0.6%
# 10                         11.6%           7.9%          5.4%
# 11                         Q2-20           2020          2019
# 12                         -5.9%           0.9%         -6.7%
# 13                          8.8%         -45.0%         20.0%
# 14                          2.7%           3.4%          2.4%
# 15                          0.39           0.40          0.50
# 16
# 17                         Q2-20           2020          2019
# 18                             5              5             5
# 19                         8,157          8,423         6,797
# 20                             0              0             0
# 21                             1              1             1
# 22                         Q2-20           2020          2019
# 23                          1.04           0.78          1.42
# 24                          0.70           0.72          1.07
# 25                          1.49           1.65          1.69
# 26                          1.61           1.83          1.75
# 27                          0.00           0.01          0.01
# 28                         Q2-20           2020          2019
# 29                          9.29          10.50         10.37
# 30                          0.91           1.02          1.11
# 31                          1.12           1.14          1.37
# 32                          3.64           3.43          3.96
# 33                          3.79           3.52          4.19
# 34                          0.28           0.26          0.39
# 35                          0.09           0.12          0.03
# 36                          1.08           1.21          1.10
# 37                          3.35           3.32          3.30
# 38                         Q2-20           2020          2019
# 39                         50.15          46.97         52.72
# 40                          5.43           4.33          5.94
# 41                         36.49          35.76         39.63
# 42                             0              0             0
# 43                          0.00           0.00          0.00
# 44
# 45                         Q2-20           2020          2019
# 46                           118            107            63
# 47                           246            197           257
# 48                            33             37            31
# 49                            14             13            14
# 50                           189            165           177
# 51                            65             63            64
# 52                             3              3             4
# 53                             4              7             4
# 54
# 55
# 56            Asset Distribution                 Institutions
# 57                < $100 million                      0 (0% )
# 58  $100 million to $250 million                      0 (0% )
# 59    $250 million to $1 billion                     3 (60% )
# 60     $1 billion to $10 billion                     2 (40% )
# 61                                > $10 billion       0 (0% )

# %%
temp_df = temp_df.replace(r'^\s*$', np.nan, regex=True)

# %%
temp_df
# Out:
#                                                  0            2       3  \
# 0                                              NaN          NaN     NaN
# 1                                              NaN          NaN     NaN
# 2                                              NaN          NaN     NaN
# 3                              ECONOMIC INDICATORS          NaN     NaN
# 4                          Employment Growth Rates        Q2-21   Q1-21
# 5                                    Total Nonfarm         6.9%   -7.2%
# 6                                    Manufacturing         9.2%   -3.6%
# 7                                            Other         3.2%  -10.6%
# 8                        Private Service-Providing         8.7%   -8.7%
# 9                                       Government         3.5%   -2.8%
# 10                               Unemployment Rate         6.6%    6.6%
# 11                                Other Indicators        Q2-21   Q1-21
# 12                      Single-Family Home Permits        25.0%   10.6%
# 13                    Multifamily Building Permits       -29.0%  -40.8%
# 14                                Home Price Index         6.8%    4.1%
# 15  Nonbusiness Bankruptcy Filings per 1000 people         0.32    0.32
# 16                                  BANKING TRENDS          NaN     NaN
# 17                             General Information        Q2-21   Q1-21
# 18                                    Institutions            5       5
# 19                                    Total Assets        9,599   8,955
# 20                                New Institutions            0       0
# 21                       Subchapter S Institutions            1       1
# 22                                   Asset Quality        Q2-21   Q1-21
# 23     Past-Due and Nonaccrual Loans / Total Loans         0.84    0.92
# 24                  Noncurrent Loans / Total Loans         0.62    0.76
# 25          Loan and Lease Allowance / Total Loans         1.69    1.59
# 26     Loan and Lease Allowance / Noncurrent Loans         2.39    1.70
# 27                   Net Loan Losses / Total Loans         0.00   -0.01
# 28                              Capital / Earnings        Q2-21   Q1-21
# 29                                 Tier 1 Leverage         9.82   10.44
# 30                                Return on Assets         1.30    1.41
# 31                         Pretax Return on Assets         1.48    1.55
# 32                             Net Interest Margin         2.96    3.13
# 33                         Yield on Earning Assets         3.12    3.16
# 34                  Cost of Funding Earning Assets         0.16    0.17
# 35                       Provisions to Avg. Assets         0.08    0.14
# 36               Noninterest Income to Avg. Assets         0.99    1.01
# 37                         Overhead to Avg. Assets         2.90    2.93
# 38                           Liquidity/Sensitivity        Q2-21   Q1-21
# 39                             Net Loans to Assets        42.26   45.98
# 40                       Noncore Funding to Assets         3.70    3.98
# 41                      Long-term Assets to Assets        37.94   38.67
# 42                               Brokered Deposits            0       0
# 43                     Brokered Deposits to Assets         0.00    0.00
# 44                             Loan Concentrations          NaN     NaN
# 45                                             NaN        Q2-21   Q1-21
# 46                       Commercial and Industrial          109     118
# 47                          Commercial Real Estate          183     190
# 48                      Construction & Development           39      38
# 49             Multifamily Residential Real Estate           13      13
# 50                      Nonresidential Real Estate          152     155
# 51                         Residential Real Estate           50      63
# 52                                        Consumer            3       3
# 53                                     Agriculture            7       7
# 54                                 BANKING PROFILE          NaN     NaN
# 55                                             NaN  Deposits ($     NaN
# 56                         Largest Deposit Markets    millions)     NaN
# 57                                   Anchorage, AK        9,374     NaN
# 58                                   Fairbanks, AK        1,947     NaN
# 59                                             NaN          NaN     NaN
# 60                                             NaN          NaN     NaN
# 61                                             NaN          NaN     NaN
#
#                                4              5             6
# 0                            NaN            NaN           NaN
# 1                            NaN            NaN        Alaska
# 2                            NaN            NaN           NaN
# 3                            NaN            NaN           NaN
# 4                          Q2-20           2020          2019
# 5                         -13.7%          -8.7%          0.7%
# 6                          -8.7%         -11.3%          3.6%
# 7                         -12.1%          -7.8%          4.5%
# 8                         -16.5%         -10.5%          0.5%
# 9                          -8.0%          -3.8%         -0.6%
# 10                         11.6%           7.9%          5.4%
# 11                         Q2-20           2020          2019
# 12                         -5.9%           0.9%         -6.7%
# 13                          8.8%         -45.0%         20.0%
# 14                          2.7%           3.4%          2.4%
# 15                          0.39           0.40          0.50
# 16                           NaN            NaN           NaN
# 17                         Q2-20           2020          2019
# 18                             5              5             5
# 19                         8,157          8,423         6,797
# 20                             0              0             0
# 21                             1              1             1
# 22                         Q2-20           2020          2019
# 23                          1.04           0.78          1.42
# 24                          0.70           0.72          1.07
# 25                          1.49           1.65          1.69
# 26                          1.61           1.83          1.75
# 27                          0.00           0.01          0.01
# 28                         Q2-20           2020          2019
# 29                          9.29          10.50         10.37
# 30                          0.91           1.02          1.11
# 31                          1.12           1.14          1.37
# 32                          3.64           3.43          3.96
# 33                          3.79           3.52          4.19
# 34                          0.28           0.26          0.39
# 35                          0.09           0.12          0.03
# 36                          1.08           1.21          1.10
# 37                          3.35           3.32          3.30
# 38                         Q2-20           2020          2019
# 39                         50.15          46.97         52.72
# 40                          5.43           4.33          5.94
# 41                         36.49          35.76         39.63
# 42                             0              0             0
# 43                          0.00           0.00          0.00
# 44                           NaN            NaN           NaN
# 45                         Q2-20           2020          2019
# 46                           118            107            63
# 47                           246            197           257
# 48                            33             37            31
# 49                            14             13            14
# 50                           189            165           177
# 51                            65             63            64
# 52                             3              3             4
# 53                             4              7             4
# 54                           NaN            NaN           NaN
# 55                           NaN            NaN           NaN
# 56            Asset Distribution            NaN  Institutions
# 57                < $100 million            NaN       0 (0% )
# 58  $100 million to $250 million            NaN       0 (0% )
# 59    $250 million to $1 billion            NaN      3 (60% )
# 60     $1 billion to $10 billion            NaN      2 (40% )
# 61                           NaN  > $10 billion       0 (0% )

# %%
temp_df = temp_df.dropna()

# %%
temp_df
# Out:
#                                                  0       2       3       4  \
# 4                          Employment Growth Rates   Q2-21   Q1-21   Q2-20
# 5                                    Total Nonfarm    6.9%   -7.2%  -13.7%
# 6                                    Manufacturing    9.2%   -3.6%   -8.7%
# 7                                            Other    3.2%  -10.6%  -12.1%
# 8                        Private Service-Providing    8.7%   -8.7%  -16.5%
# 9                                       Government    3.5%   -2.8%   -8.0%
# 10                               Unemployment Rate    6.6%    6.6%   11.6%
# 11                                Other Indicators   Q2-21   Q1-21   Q2-20
# 12                      Single-Family Home Permits   25.0%   10.6%   -5.9%
# 13                    Multifamily Building Permits  -29.0%  -40.8%    8.8%
# 14                                Home Price Index    6.8%    4.1%    2.7%
# 15  Nonbusiness Bankruptcy Filings per 1000 people    0.32    0.32    0.39
# 17                             General Information   Q2-21   Q1-21   Q2-20
# 18                                    Institutions       5       5       5
# 19                                    Total Assets   9,599   8,955   8,157
# 20                                New Institutions       0       0       0
# 21                       Subchapter S Institutions       1       1       1
# 22                                   Asset Quality   Q2-21   Q1-21   Q2-20
# 23     Past-Due and Nonaccrual Loans / Total Loans    0.84    0.92    1.04
# 24                  Noncurrent Loans / Total Loans    0.62    0.76    0.70
# 25          Loan and Lease Allowance / Total Loans    1.69    1.59    1.49
# 26     Loan and Lease Allowance / Noncurrent Loans    2.39    1.70    1.61
# 27                   Net Loan Losses / Total Loans    0.00   -0.01    0.00
# 28                              Capital / Earnings   Q2-21   Q1-21   Q2-20
# 29                                 Tier 1 Leverage    9.82   10.44    9.29
# 30                                Return on Assets    1.30    1.41    0.91
# 31                         Pretax Return on Assets    1.48    1.55    1.12
# 32                             Net Interest Margin    2.96    3.13    3.64
# 33                         Yield on Earning Assets    3.12    3.16    3.79
# 34                  Cost of Funding Earning Assets    0.16    0.17    0.28
# 35                       Provisions to Avg. Assets    0.08    0.14    0.09
# 36               Noninterest Income to Avg. Assets    0.99    1.01    1.08
# 37                         Overhead to Avg. Assets    2.90    2.93    3.35
# 38                           Liquidity/Sensitivity   Q2-21   Q1-21   Q2-20
# 39                             Net Loans to Assets   42.26   45.98   50.15
# 40                       Noncore Funding to Assets    3.70    3.98    5.43
# 41                      Long-term Assets to Assets   37.94   38.67   36.49
# 42                               Brokered Deposits       0       0       0
# 43                     Brokered Deposits to Assets    0.00    0.00    0.00
# 46                       Commercial and Industrial     109     118     118
# 47                          Commercial Real Estate     183     190     246
# 48                      Construction & Development      39      38      33
# 49             Multifamily Residential Real Estate      13      13      14
# 50                      Nonresidential Real Estate     152     155     189
# 51                         Residential Real Estate      50      63      65
# 52                                        Consumer       3       3       3
# 53                                     Agriculture       7       7       4
#
#          5      6
# 4     2020   2019
# 5    -8.7%   0.7%
# 6   -11.3%   3.6%
# 7    -7.8%   4.5%
# 8   -10.5%   0.5%
# 9    -3.8%  -0.6%
# 10    7.9%   5.4%
# 11    2020   2019
# 12    0.9%  -6.7%
# 13  -45.0%  20.0%
# 14    3.4%   2.4%
# 15    0.40   0.50
# 17    2020   2019
# 18       5      5
# 19   8,423  6,797
# 20       0      0
# 21       1      1
# 22    2020   2019
# 23    0.78   1.42
# 24    0.72   1.07
# 25    1.65   1.69
# 26    1.83   1.75
# 27    0.01   0.01
# 28    2020   2019
# 29   10.50  10.37
# 30    1.02   1.11
# 31    1.14   1.37
# 32    3.43   3.96
# 33    3.52   4.19
# 34    0.26   0.39
# 35    0.12   0.03
# 36    1.21   1.10
# 37    3.32   3.30
# 38    2020   2019
# 39   46.97  52.72
# 40    4.33   5.94
# 41   35.76  39.63
# 42       0      0
# 43    0.00   0.00
# 46     107     63
# 47     197    257
# 48      37     31
# 49      13     14
# 50     165    177
# 51      63     64
# 52       3      4
# 53       7      4

# %%
temp_df = temp_df.reset_index(drop = True)

# %%
temp_df
# Out:
#                                                  0       2       3       4  \
# 0                          Employment Growth Rates   Q2-21   Q1-21   Q2-20
# 1                                    Total Nonfarm    6.9%   -7.2%  -13.7%
# 2                                    Manufacturing    9.2%   -3.6%   -8.7%
# 3                                            Other    3.2%  -10.6%  -12.1%
# 4                        Private Service-Providing    8.7%   -8.7%  -16.5%
# 5                                       Government    3.5%   -2.8%   -8.0%
# 6                                Unemployment Rate    6.6%    6.6%   11.6%
# 7                                 Other Indicators   Q2-21   Q1-21   Q2-20
# 8                       Single-Family Home Permits   25.0%   10.6%   -5.9%
# 9                     Multifamily Building Permits  -29.0%  -40.8%    8.8%
# 10                                Home Price Index    6.8%    4.1%    2.7%
# 11  Nonbusiness Bankruptcy Filings per 1000 people    0.32    0.32    0.39
# 12                             General Information   Q2-21   Q1-21   Q2-20
# 13                                    Institutions       5       5       5
# 14                                    Total Assets   9,599   8,955   8,157
# 15                                New Institutions       0       0       0
# 16                       Subchapter S Institutions       1       1       1
# 17                                   Asset Quality   Q2-21   Q1-21   Q2-20
# 18     Past-Due and Nonaccrual Loans / Total Loans    0.84    0.92    1.04
# 19                  Noncurrent Loans / Total Loans    0.62    0.76    0.70
# 20          Loan and Lease Allowance / Total Loans    1.69    1.59    1.49
# 21     Loan and Lease Allowance / Noncurrent Loans    2.39    1.70    1.61
# 22                   Net Loan Losses / Total Loans    0.00   -0.01    0.00
# 23                              Capital / Earnings   Q2-21   Q1-21   Q2-20
# 24                                 Tier 1 Leverage    9.82   10.44    9.29
# 25                                Return on Assets    1.30    1.41    0.91
# 26                         Pretax Return on Assets    1.48    1.55    1.12
# 27                             Net Interest Margin    2.96    3.13    3.64
# 28                         Yield on Earning Assets    3.12    3.16    3.79
# 29                  Cost of Funding Earning Assets    0.16    0.17    0.28
# 30                       Provisions to Avg. Assets    0.08    0.14    0.09
# 31               Noninterest Income to Avg. Assets    0.99    1.01    1.08
# 32                         Overhead to Avg. Assets    2.90    2.93    3.35
# 33                           Liquidity/Sensitivity   Q2-21   Q1-21   Q2-20
# 34                             Net Loans to Assets   42.26   45.98   50.15
# 35                       Noncore Funding to Assets    3.70    3.98    5.43
# 36                      Long-term Assets to Assets   37.94   38.67   36.49
# 37                               Brokered Deposits       0       0       0
# 38                     Brokered Deposits to Assets    0.00    0.00    0.00
# 39                       Commercial and Industrial     109     118     118
# 40                          Commercial Real Estate     183     190     246
# 41                      Construction & Development      39      38      33
# 42             Multifamily Residential Real Estate      13      13      14
# 43                      Nonresidential Real Estate     152     155     189
# 44                         Residential Real Estate      50      63      65
# 45                                        Consumer       3       3       3
# 46                                     Agriculture       7       7       4
#
#          5      6
# 0     2020   2019
# 1    -8.7%   0.7%
# 2   -11.3%   3.6%
# 3    -7.8%   4.5%
# 4   -10.5%   0.5%
# 5    -3.8%  -0.6%
# 6     7.9%   5.4%
# 7     2020   2019
# 8     0.9%  -6.7%
# 9   -45.0%  20.0%
# 10    3.4%   2.4%
# 11    0.40   0.50
# 12    2020   2019
# 13       5      5
# 14   8,423  6,797
# 15       0      0
# 16       1      1
# 17    2020   2019
# 18    0.78   1.42
# 19    0.72   1.07
# 20    1.65   1.69
# 21    1.83   1.75
# 22    0.01   0.01
# 23    2020   2019
# 24   10.50  10.37
# 25    1.02   1.11
# 26    1.14   1.37
# 27    3.43   3.96
# 28    3.52   4.19
# 29    0.26   0.39
# 30    0.12   0.03
# 31    1.21   1.10
# 32    3.32   3.30
# 33    2020   2019
# 34   46.97  52.72
# 35    4.33   5.94
# 36   35.76  39.63
# 37       0      0
# 38    0.00   0.00
# 39     107     63
# 40     197    257
# 41      37     31
# 42      13     14
# 43     165    177
# 44      63     64
# 45       3      4
# 46       7      4

# %%
# temp_df = temp_df.drop(temp_df.index[0])
# temp_df.rename(columns={'Employment Growth Rates': 'ECONOMIC INDICATORS'}, inplace=True)

# %%
temp_df.columns = temp_df.iloc[0]

# %%
temp_df.columns
# Out:
# Index(['Employment Growth Rates', 'Q2-21', 'Q1-21', 'Q2-20', '2020', '2019'], dtype='object', name=0)

# %%
temp_df = temp_df.drop(temp_df.index[0])
temp_df.rename(columns={'Employment Growth Rates': 'ECONOMIC INDICATORS'}, inplace=True)

# %%
temp_df
# Out:
# 0                              ECONOMIC INDICATORS   Q2-21   Q1-21   Q2-20  \
# 1                                    Total Nonfarm    6.9%   -7.2%  -13.7%
# 2                                    Manufacturing    9.2%   -3.6%   -8.7%
# 3                                            Other    3.2%  -10.6%  -12.1%
# 4                        Private Service-Providing    8.7%   -8.7%  -16.5%
# 5                                       Government    3.5%   -2.8%   -8.0%
# 6                                Unemployment Rate    6.6%    6.6%   11.6%
# 7                                 Other Indicators   Q2-21   Q1-21   Q2-20
# 8                       Single-Family Home Permits   25.0%   10.6%   -5.9%
# 9                     Multifamily Building Permits  -29.0%  -40.8%    8.8%
# 10                                Home Price Index    6.8%    4.1%    2.7%
# 11  Nonbusiness Bankruptcy Filings per 1000 people    0.32    0.32    0.39
# 12                             General Information   Q2-21   Q1-21   Q2-20
# 13                                    Institutions       5       5       5
# 14                                    Total Assets   9,599   8,955   8,157
# 15                                New Institutions       0       0       0
# 16                       Subchapter S Institutions       1       1       1
# 17                                   Asset Quality   Q2-21   Q1-21   Q2-20
# 18     Past-Due and Nonaccrual Loans / Total Loans    0.84    0.92    1.04
# 19                  Noncurrent Loans / Total Loans    0.62    0.76    0.70
# 20          Loan and Lease Allowance / Total Loans    1.69    1.59    1.49
# 21     Loan and Lease Allowance / Noncurrent Loans    2.39    1.70    1.61
# 22                   Net Loan Losses / Total Loans    0.00   -0.01    0.00
# 23                              Capital / Earnings   Q2-21   Q1-21   Q2-20
# 24                                 Tier 1 Leverage    9.82   10.44    9.29
# 25                                Return on Assets    1.30    1.41    0.91
# 26                         Pretax Return on Assets    1.48    1.55    1.12
# 27                             Net Interest Margin    2.96    3.13    3.64
# 28                         Yield on Earning Assets    3.12    3.16    3.79
# 29                  Cost of Funding Earning Assets    0.16    0.17    0.28
# 30                       Provisions to Avg. Assets    0.08    0.14    0.09
# 31               Noninterest Income to Avg. Assets    0.99    1.01    1.08
# 32                         Overhead to Avg. Assets    2.90    2.93    3.35
# 33                           Liquidity/Sensitivity   Q2-21   Q1-21   Q2-20
# 34                             Net Loans to Assets   42.26   45.98   50.15
# 35                       Noncore Funding to Assets    3.70    3.98    5.43
# 36                      Long-term Assets to Assets   37.94   38.67   36.49
# 37                               Brokered Deposits       0       0       0
# 38                     Brokered Deposits to Assets    0.00    0.00    0.00
# 39                       Commercial and Industrial     109     118     118
# 40                          Commercial Real Estate     183     190     246
# 41                      Construction & Development      39      38      33
# 42             Multifamily Residential Real Estate      13      13      14
# 43                      Nonresidential Real Estate     152     155     189
# 44                         Residential Real Estate      50      63      65
# 45                                        Consumer       3       3       3
# 46                                     Agriculture       7       7       4
#
# 0     2020   2019
# 1    -8.7%   0.7%
# 2   -11.3%   3.6%
# 3    -7.8%   4.5%
# 4   -10.5%   0.5%
# 5    -3.8%  -0.6%
# 6     7.9%   5.4%
# 7     2020   2019
# 8     0.9%  -6.7%
# 9   -45.0%  20.0%
# 10    3.4%   2.4%
# 11    0.40   0.50
# 12    2020   2019
# 13       5      5
# 14   8,423  6,797
# 15       0      0
# 16       1      1
# 17    2020   2019
# 18    0.78   1.42
# 19    0.72   1.07
# 20    1.65   1.69
# 21    1.83   1.75
# 22    0.01   0.01
# 23    2020   2019
# 24   10.50  10.37
# 25    1.02   1.11
# 26    1.14   1.37
# 27    3.43   3.96
# 28    3.52   4.19
# 29    0.26   0.39
# 30    0.12   0.03
# 31    1.21   1.10
# 32    3.32   3.30
# 33    2020   2019
# 34   46.97  52.72
# 35    4.33   5.94
# 36   35.76  39.63
# 37       0      0
# 38    0.00   0.00
# 39     107     63
# 40     197    257
# 41      37     31
# 42      13     14
# 43     165    177
# 44      63     64
# 45       3      4
# 46       7      4

# %%
temp_df = temp_df.reset_index(drop = True)
filter_df = pd.DataFrame()
filter_df['Category'] = ""
for i in range(len(temp_df)):
    eco_indi = temp_df['ECONOMIC INDICATORS'][i]
    for key,value in dict_fetch.items():
        if key == eco_indi:
            filter_df = filter_df.append(temp_df[temp_df['ECONOMIC INDICATORS'] == eco_indi])
            filter_df['Category'][i] = value
filter_df = filter_df[['ECONOMIC INDICATORS', 'Q2-21', 'Q1-21', 'Q2-20', '2020', '2019', 'Category']]
filter_df = filter_df.reset_index(drop = True)
filter_df['state_alias'] = (file_path.split('/')[-1]).split('.')[0]

# %%
filter_df
# Out:
#                             ECONOMIC INDICATORS  Q2-21  Q1-21  Q2-20   2020  \
# 0   Past-Due and Nonaccrual Loans / Total Loans   0.84   0.92   1.04   0.78
# 1                Noncurrent Loans / Total Loans   0.62   0.76   0.70   0.72
# 2        Loan and Lease Allowance / Total Loans   1.69   1.59   1.49   1.65
# 3   Loan and Lease Allowance / Noncurrent Loans   2.39   1.70   1.61   1.83
# 4                 Net Loan Losses / Total Loans   0.00  -0.01   0.00   0.01
# 5                              Return on Assets   1.30   1.41   0.91   1.02
# 6                           Net Interest Margin   2.96   3.13   3.64   3.43
# 7                       Yield on Earning Assets   3.12   3.16   3.79   3.52
# 8                Cost of Funding Earning Assets   0.16   0.17   0.28   0.26
# 9                     Provisions to Avg. Assets   0.08   0.14   0.09   0.12
# 10                      Overhead to Avg. Assets   2.90   2.93   3.35   3.32
# 11                          Net Loans to Assets  42.26  45.98  50.15  46.97
# 12                   Long-term Assets to Assets  37.94  38.67  36.49  35.76
#
#      2019       Category state_alias
# 0    1.42  Asset Quality          ak
# 1    1.07  Asset Quality          ak
# 2    1.69  Asset Quality          ak
# 3    1.75  Asset Quality          ak
# 4    0.01  Asset Quality          ak
# 5    1.11       Earnings          ak
# 6    3.96       Earnings          ak
# 7    4.19       Earnings          ak
# 8    0.39       Earnings          ak
# 9    0.03       Earnings          ak
# 10   3.30       Earnings          ak
# 11  52.72      Liquidity          ak
# 12  39.63      Liquidity          ak
