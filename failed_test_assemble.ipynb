# %%
import os
import camelot
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
dict_fetch = {"Past-Due and Nonaccrual Loans / Total Loans" : "Asset Quality",
              "Noncurrent Loans / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Total Loans" : "Asset Quality",
              "Loan and Lease Allowance / Noncurrent Loans" : "Asset Quality",
              "Net Loan Losses / Total Loans" : "Asset Quality",
              "Return on Assets" : "Earnings",
              "Net Interest Margin" : "Earnings",
              "Yield on Earning Assets" : "Earnings",
              "Cost of Funding Earning Assets" : "Earnings",
              "Provisions to Avg. Assets" : "Earnings",
              "Overhead to Avg. Assets" : "Earnings",
              "Net Loans to Assets" : "Liquidity",
              "Long-term Assets to Assets" : "Liquidity"
            }

# %%
file_path = '/home/shubha/work/byteiq_tasks/fdic/download/wy.pdf'

# %%
tables = camelot.read_pdf(filepath=file_path,flavor='stream',edge_tol=1500)
temp_df = tables[1].df
remove_from_bracket = lambda text : text.split('(', 1)[0]
remove_spaces = lambda text : text.strip()
temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)
# temp_df = temp_df.drop([1], axis=1)
temp_df = temp_df.replace(r'^\s*$', np.nan, regex=True)
temp_df = temp_df.dropna()
temp_df = temp_df.reset_index(drop = True)
temp_df.columns = temp_df.iloc[0]
temp_df = temp_df.drop(temp_df.index[0])
temp_df.rename(columns={'Employment Growth Rates': 'ECONOMIC INDICATORS'}, inplace=True)
temp_df = temp_df.reset_index(drop = True)
filter_df = pd.DataFrame()
filter_df['Category'] = ""
for i in range(len(temp_df)):
    eco_indi = temp_df['ECONOMIC INDICATORS'][i]
    for key,value in dict_fetch.items():
        if key == eco_indi:
            filter_df = filter_df.append(temp_df[temp_df['ECONOMIC INDICATORS'] == eco_indi])
            filter_df['Category'][i] = value
filter_df = filter_df[['ECONOMIC INDICATORS', 'Q2-21', 'Q1-21', 'Q2-20', '2020', '2019', 'Category']]
filter_df = filter_df.reset_index(drop = True)
filter_df['state_alias'] = (file_path.split('/')[-1]).split('.')[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ECONOMIC INDICATORS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23175/4243695865.py in <module>
#      15 filter_df['Category'] = ""
#      16 for i in range(len(temp_df)):
# ---> 17     eco_indi = temp_df['ECONOMIC INDICATORS'][i]
#      18     for key,value in dict_fetch.items():
#      19         if key == eco_indi:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ECONOMIC INDICATORS'

# %%
tables = camelot.read_pdf(filepath=file_path,flavor='stream',edge_tol=1500)
temp_df = tables[0].df
remove_from_bracket = lambda text : text.split('(', 1)[0]
remove_spaces = lambda text : text.strip()
temp_df[0] = temp_df[0].map(remove_from_bracket).map(remove_spaces)
temp_df = temp_df.drop([1], axis=1)
temp_df = temp_df.replace(r'^\s*$', np.nan, regex=True)
temp_df = temp_df.dropna()
temp_df = temp_df.reset_index(drop = True)
temp_df.columns = temp_df.iloc[0]
temp_df = temp_df.drop(temp_df.index[0])
temp_df.rename(columns={'Employment Growth Rates': 'ECONOMIC INDICATORS'}, inplace=True)
temp_df = temp_df.reset_index(drop = True)
filter_df = pd.DataFrame()
filter_df['Category'] = ""
for i in range(len(temp_df)):
    eco_indi = temp_df['ECONOMIC INDICATORS'][i]
    for key,value in dict_fetch.items():
        if key == eco_indi:
            filter_df = filter_df.append(temp_df[temp_df['ECONOMIC INDICATORS'] == eco_indi])
            filter_df['Category'][i] = value
filter_df = filter_df[['ECONOMIC INDICATORS', 'Q2-21', 'Q1-21', 'Q2-20', '2020', '2019', 'Category']]
filter_df = filter_df.reset_index(drop = True)
filter_df['state_alias'] = (file_path.split('/')[-1]).split('.')[0]

# %%
filter_df
# Out:
#                             ECONOMIC INDICATORS  Q2-21  Q1-21  Q2-20   2020  \
# 0   Past-Due and Nonaccrual Loans / Total Loans   0.43   0.58   0.82   0.74
# 1                Noncurrent Loans / Total Loans   0.19   0.21   0.33   0.21
# 2        Loan and Lease Allowance / Total Loans   1.67   1.75   1.51   1.80
# 3   Loan and Lease Allowance / Noncurrent Loans   4.91   5.44   3.68   4.82
# 4                 Net Loan Losses / Total Loans   0.00   0.00   0.01   0.03
# 5                              Return on Assets   1.20   1.26   1.07   1.03
# 6                           Net Interest Margin   3.46   3.15   3.90   3.68
# 7                       Yield on Earning Assets   3.70   3.42   4.47   4.13
# 8                Cost of Funding Earning Assets   0.28   0.31   0.60   0.50
# 9                     Provisions to Avg. Assets   0.00   0.00   0.21   0.15
# 10                      Overhead to Avg. Assets   2.43   2.39   2.75   2.66
# 11                          Net Loans to Assets  50.64  50.06  55.67  49.08
# 12                   Long-term Assets to Assets  43.48  43.76  34.62  40.93
#
#      2019       Category state_alias
# 0    0.89  Asset Quality          wy
# 1    0.40  Asset Quality          wy
# 2    1.61  Asset Quality          wy
# 3    3.72  Asset Quality          wy
# 4    0.05  Asset Quality          wy
# 5    1.10       Earnings          wy
# 6    3.98       Earnings          wy
# 7    4.52       Earnings          wy
# 8    0.70       Earnings          wy
# 9    0.05       Earnings          wy
# 10   2.92       Earnings          wy
# 11  56.98      Liquidity          wy
# 12  33.47      Liquidity          wy

# %%
filter_df

# %%
filter_df
